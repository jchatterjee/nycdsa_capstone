# %% [markdown]
# ### ML Question 4: Data Cleaning

# %% [markdown]
# Import all necessary packages.

# %%
# Apache parquet files (to save space)
import pyarrow as pa
import pyarrow.parquet as pq

# Dataframes and numerical
import pandas as pd
import numpy as np
import statistics

# Increase pandas default display 
pd.options.display.max_rows = 250
pd.options.display.max_columns = 250

# Suppress scientific notation of data in pandas
pd.set_option('display.float_format', '{:.2f}'.format)

# Graphing
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set_style('darkgrid')
plt.style.use('fivethirtyeight')

# For data preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats

# Library for model creation
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.linear_model import Lasso
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split,GridSearchCV

# Model evaluation
from sklearn.metrics import mean_squared_error,r2_score

# Silence warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load **.parquet** file of all CitiBike rides from May 2021 through April 2022 into **pandas** dataframe.

# %%
CB_Data = pq.read_table('data/202105-202204-citibike-tripdata.parquet').to_pandas()

# %% [markdown]
# Preview the dataset.

# %%
CB_Data.head()
# Out:
#   member_casual rideable_type          started_at        start_station_name  \
# 1        Member  Classic Bike 2021-05-13 12:48:08        Broadway & W 25 St
# 2        Member  Classic Bike 2021-05-16 08:30:13             46 Ave & 5 St
# 3        Member  Classic Bike 2021-05-01 08:38:14             46 Ave & 5 St
# 4        Member  Classic Bike 2021-05-09 08:12:31             46 Ave & 5 St
# 5        Member  Classic Bike 2021-05-27 07:52:27  E 123 St & Lexington Ave
#
#    start_lat  start_lng start_boro         start_hood            ended_at  \
# 1      40.74     -73.99  Manhattan  Flatiron District 2021-05-13 13:07:37
# 2      40.75     -73.95     Queens   Long Island City 2021-05-16 08:45:47
# 3      40.75     -73.95     Queens   Long Island City 2021-05-01 08:54:27
# 4      40.75     -73.95     Queens   Long Island City 2021-05-09 08:27:05
# 5      40.80     -73.94  Manhattan        East Harlem 2021-05-27 08:09:01
#
#          end_station_name  end_lat  end_lng   end_boro          end_hood  \
# 1       E 2 St & Avenue B    40.72   -73.98  Manhattan      East Village
# 2  34th Ave & Vernon Blvd    40.77   -73.94     Queens  Long Island City
# 3  34th Ave & Vernon Blvd    40.77   -73.94     Queens  Long Island City
# 4  34th Ave & Vernon Blvd    40.77   -73.94     Queens  Long Island City
# 5         1 Ave & E 78 St    40.77   -73.95  Manhattan   Upper East Side
#
#    year  month  week_of_year  day_of_week  hour_of_day  duration_min  \
# 1  2021      5            19            3           12         19.48
# 2  2021      5            19            6            8         15.57
# 3  2021      5            17            5            8         16.22
# 4  2021      5            18            6            8         14.57
# 5  2021      5            21            3            7         16.57
#
#    distance_mi  speed_mph
# 1         1.81       5.57
# 2         2.26       8.69
# 3         2.26       8.35
# 4         2.26       9.29
# 5         3.25      11.78

# %%
CB_Data.tail()
# Out:
#          member_casual  rideable_type          started_at  \
# 28816543        Member   Classic Bike 2022-04-22 13:08:15
# 28816544        Member   Classic Bike 2022-04-13 17:10:49
# 28816545        Member   Classic Bike 2022-04-12 15:58:47
# 28816546        Member  Electric Bike 2022-04-28 15:52:49
# 28816547        Member  Electric Bike 2022-04-11 19:55:31
#
#                           start_station_name  start_lat  start_lng start_boro  \
# 28816543             Allen St & Rivington St      40.72     -73.99  Manhattan
# 28816544  St. Nicholas Terrace & Convent Ave      40.82     -73.95  Manhattan
# 28816545                     E 88 St & 1 Ave      40.78     -73.95  Manhattan
# 28816546                     W 55 St & 6 Ave      40.76     -73.98  Manhattan
# 28816547              W 87 St & West End Ave      40.79     -73.98  Manhattan
#
#                start_hood            ended_at            end_station_name  \
# 28816543  Lower East Side 2022-04-22 13:29:31             W 29 St & 9 Ave
# 28816544           Harlem 2022-04-13 17:26:08  E 138 St & Grand Concourse
# 28816545  Upper East Side 2022-04-12 16:41:17             E 91 St & 2 Ave
# 28816546          Midtown 2022-04-28 16:06:31             E 91 St & 2 Ave
# 28816547  Upper West Side 2022-04-11 20:09:19             E 91 St & 2 Ave
#
#           end_lat  end_lng   end_boro         end_hood  year  month  \
# 28816543    40.75   -74.00  Manhattan          Chelsea  2022      4
# 28816544    40.81   -73.93      Bronx       Mott Haven  2022      4
# 28816545    40.78   -73.95  Manhattan  Upper East Side  2022      4
# 28816546    40.78   -73.95  Manhattan  Upper East Side  2022      4
# 28816547    40.78   -73.95  Manhattan  Upper East Side  2022      4
#
#           week_of_year  day_of_week  hour_of_day  duration_min  distance_mi  \
# 28816543            16            4           13         21.27         2.64
# 28816544            15            2           17         15.32         1.75
# 28816545            15            1           15         42.50         0.25
# 28816546            17            3           15         13.70         3.23
# 28816547            15            0           19         13.80         2.51
#
#           speed_mph
# 28816543       7.45
# 28816544       6.85
# 28816545       0.36
# 28816546      14.13
# 28816547      10.92

# %% [markdown]
# Description of the dataset.

# %%
CB_Data.describe(include='all').T
# Out:
#                          count    unique                  top      freq  \
# member_casual         27143436         2               Member  20092339
# rideable_type         27143436         2         Classic Bike  19461880
# started_at            27143436  15052189  2021-08-20 17:29:55        40
# start_station_name    27143436      1588      W 21 St & 6 Ave    128058
# start_lat          27143436.00       NaN                  NaN       NaN
# start_lng          27143436.00       NaN                  NaN       NaN
# start_boro            27143436         5            Manhattan  19674401
# start_hood            27143436        89              Chelsea   2073923
# ended_at              27143436  15064923  2021-05-05 23:31:09        60
# end_station_name      27143436      1668      W 21 St & 6 Ave    129117
# end_lat            27143436.00       NaN                  NaN       NaN
# end_lng            27143436.00       NaN                  NaN       NaN
# end_boro              27143436         5            Manhattan  19639748
# end_hood              27143436        90              Chelsea   2078122
# year               27143436.00       NaN                  NaN       NaN
# month              27143436.00       NaN                  NaN       NaN
# week_of_year       27143436.00       NaN                  NaN       NaN
# day_of_week        27143436.00       NaN                  NaN       NaN
# hour_of_day        27143436.00       NaN                  NaN       NaN
# duration_min       27143436.00       NaN                  NaN       NaN
# distance_mi        27143436.00       NaN                  NaN       NaN
# speed_mph          27143436.00       NaN                  NaN       NaN
#
#                                  first                last    mean    std  \
# member_casual                      NaT                 NaT     NaN    NaN
# rideable_type                      NaT                 NaT     NaN    NaN
# started_at         2021-05-01 00:00:01 2022-04-30 23:59:59     NaN    NaN
# start_station_name                 NaT                 NaT     NaN    NaN
# start_lat                          NaT                 NaT   40.74   0.04
# start_lng                          NaT                 NaT  -73.98   0.02
# start_boro                         NaT                 NaT     NaN    NaN
# start_hood                         NaT                 NaT     NaN    NaN
# ended_at           2021-05-01 00:02:01 2022-05-01 21:40:03     NaN    NaN
# end_station_name                   NaT                 NaT     NaN    NaN
# end_lat                            NaT                 NaT   40.74   0.04
# end_lng                            NaT                 NaT  -73.98   0.02
# end_boro                           NaT                 NaT     NaN    NaN
# end_hood                           NaT                 NaT     NaN    NaN
# year                               NaT                 NaT 2021.23   0.42
# month                              NaT                 NaT    7.03   2.98
# week_of_year                       NaT                 NaT   28.45  12.91
# day_of_week                        NaT                 NaT    2.97   1.95
# hour_of_day                        NaT                 NaT   14.04   5.02
# duration_min                       NaT                 NaT   16.63 299.17
# distance_mi                        NaT                 NaT    1.76   1.43
# speed_mph                          NaT                 NaT     inf    NaN
#
#                          min     25%     50%     75%       max
# member_casual            NaN     NaN     NaN     NaN       NaN
# rideable_type            NaN     NaN     NaN     NaN       NaN
# started_at               NaN     NaN     NaN     NaN       NaN
# start_station_name       NaN     NaN     NaN     NaN       NaN
# start_lat              40.63   40.72   40.74   40.76     40.88
# start_lng             -74.04  -73.99  -73.98  -73.96    -73.88
# start_boro               NaN     NaN     NaN     NaN       NaN
# start_hood               NaN     NaN     NaN     NaN       NaN
# ended_at                 NaN     NaN     NaN     NaN       NaN
# end_station_name         NaN     NaN     NaN     NaN       NaN
# end_lat                40.63   40.72   40.74   40.76     40.88
# end_lng               -74.08  -73.99  -73.98  -73.96    -73.88
# end_boro                 NaN     NaN     NaN     NaN       NaN
# end_hood                 NaN     NaN     NaN     NaN       NaN
# year                 2021.00 2021.00 2021.00 2021.00   2022.00
# month                   1.00    5.00    7.00    9.00     12.00
# week_of_year            1.00   19.00   29.00   39.00     52.00
# day_of_week             0.00    1.00    3.00    5.00      6.00
# hour_of_day             0.00   11.00   15.00   18.00     23.00
# duration_min        -5929.82    6.17   10.62   18.38 263605.68
# distance_mi             0.00    0.79    1.35    2.27     22.56
# speed_mph          -28819.15    6.27    8.40   10.63       inf

# %% [markdown]
# While the EDA illustrated the distribution of rides in terms of time and location, there appears to be irregularities in the data with respect to calculated values such as ride duration, and speed. How is a negative ride duration possible? This needs to be explored in a univariate analysis of **duration_min**, which will directly affect **speed_mph**.

# %%
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.duration_min)
plt.show()

# %% [markdown]
# The negative ride durations are adversely affecting the plotting of the density of this data. Investigate where such durations are.

# %%
CB_neg_ride = CB_Data.loc[CB_Data.duration_min <= 0]

# %%
CB_neg_ride.shape
# Out:
# (4374, 22)

# %%
CB_neg_ride.head()
# Out:
#      member_casual rideable_type          started_at       start_station_name  \
# 1458        Member  Classic Bike 2021-05-24 20:12:57  Centre St & Chambers St
# 4638        Member  Classic Bike 2021-05-27 19:56:48    Allen St & Stanton St
# 5523        Casual  Classic Bike 2021-05-21 20:48:46     Broad St & Bridge St
# 6299        Member  Classic Bike 2021-05-23 10:04:03          8 Ave & W 33 St
# 7042        Casual  Classic Bike 2021-05-28 11:57:10   Huron St & Franklin St
#
#       start_lat  start_lng start_boro          start_hood            ended_at  \
# 1458      40.71     -74.00  Manhattan        Civic Center 2021-05-24 20:12:35
# 4638      40.72     -73.99  Manhattan     Lower East Side 2021-05-27 19:56:25
# 5523      40.70     -74.01  Manhattan  Financial District 2021-05-21 20:48:07
# 6299      40.75     -73.99  Manhattan             Chelsea 2021-05-23 10:03:38
# 7042      40.73     -73.96   Brooklyn          Greenpoint 2021-05-28 11:57:09
#
#               end_station_name  end_lat  end_lng   end_boro  \
# 1458    Warren St & W Broadway    40.71   -74.01  Manhattan
# 4638   Stanton St & Norfolk St    40.72   -73.99  Manhattan
# 5523      Maiden Ln & Pearl St    40.71   -74.01  Manhattan
# 6299   Lexington Ave & E 36 St    40.75   -73.98  Manhattan
# 7042  Banker St & Meserole Ave    40.73   -73.96   Brooklyn
#
#                 end_hood  year  month  week_of_year  day_of_week  hour_of_day  \
# 1458             Tribeca  2021      5            21            0           20
# 4638     Lower East Side  2021      5            21            3           19
# 5523  Financial District  2021      5            20            4           20
# 6299         Murray Hill  2021      5            20            6           10
# 7042          Greenpoint  2021      5            21            4           11
#
#       duration_min  distance_mi  speed_mph
# 1458         -0.37         0.45     -73.46
# 4638         -0.38         0.29     -44.76
# 5523         -0.65         0.54     -49.50
# 6299         -0.42         1.32    -189.88
# 7042         -0.02         0.60   -2148.31

# %% [markdown]
# Most that 4,000 of these rides have unexplained errors in their data collection and need to be discarded.

# %%
CB_Data = CB_Data[~(CB_Data.duration_min <= 0)]

# %%
CB_Data.describe(include='all').T
# Out:
#                          count    unique                  top      freq  \
# member_casual         27139062         2               Member  20088636
# rideable_type         27139062         2         Classic Bike  19457695
# started_at            27139062  15050603  2021-08-20 17:29:55        40
# start_station_name    27139062      1588      W 21 St & 6 Ave    128050
# start_lat          27139062.00       NaN                  NaN       NaN
# start_lng          27139062.00       NaN                  NaN       NaN
# start_boro            27139062         5            Manhattan  19670692
# start_hood            27139062        89              Chelsea   2073596
# ended_at              27139062  15063410  2021-05-05 23:31:09        60
# end_station_name      27139062      1668      W 21 St & 6 Ave    129110
# end_lat            27139062.00       NaN                  NaN       NaN
# end_lng            27139062.00       NaN                  NaN       NaN
# end_boro              27139062         5            Manhattan  19636045
# end_hood              27139062        90              Chelsea   2077871
# year               27139062.00       NaN                  NaN       NaN
# month              27139062.00       NaN                  NaN       NaN
# week_of_year       27139062.00       NaN                  NaN       NaN
# day_of_week        27139062.00       NaN                  NaN       NaN
# hour_of_day        27139062.00       NaN                  NaN       NaN
# duration_min       27139062.00       NaN                  NaN       NaN
# distance_mi        27139062.00       NaN                  NaN       NaN
# speed_mph          27139062.00       NaN                  NaN       NaN
#
#                                  first                last    mean    std  \
# member_casual                      NaT                 NaT     NaN    NaN
# rideable_type                      NaT                 NaT     NaN    NaN
# started_at         2021-05-01 00:00:01 2022-04-30 23:59:59     NaN    NaN
# start_station_name                 NaT                 NaT     NaN    NaN
# start_lat                          NaT                 NaT   40.74   0.04
# start_lng                          NaT                 NaT  -73.98   0.02
# start_boro                         NaT                 NaT     NaN    NaN
# start_hood                         NaT                 NaT     NaN    NaN
# ended_at           2021-05-01 00:02:01 2022-05-01 21:40:03     NaN    NaN
# end_station_name                   NaT                 NaT     NaN    NaN
# end_lat                            NaT                 NaT   40.74   0.04
# end_lng                            NaT                 NaT  -73.98   0.02
# end_boro                           NaT                 NaT     NaN    NaN
# end_hood                           NaT                 NaT     NaN    NaN
# year                               NaT                 NaT 2021.23   0.42
# month                              NaT                 NaT    7.03   2.98
# week_of_year                       NaT                 NaT   28.45  12.91
# day_of_week                        NaT                 NaT    2.97   1.95
# hour_of_day                        NaT                 NaT   14.04   5.02
# duration_min                       NaT                 NaT   16.63 299.18
# distance_mi                        NaT                 NaT    1.76   1.43
# speed_mph                          NaT                 NaT    8.46   5.26
#
#                        min     25%     50%     75%       max
# member_casual          NaN     NaN     NaN     NaN       NaN
# rideable_type          NaN     NaN     NaN     NaN       NaN
# started_at             NaN     NaN     NaN     NaN       NaN
# start_station_name     NaN     NaN     NaN     NaN       NaN
# start_lat            40.63   40.72   40.74   40.76     40.88
# start_lng           -74.04  -73.99  -73.98  -73.96    -73.88
# start_boro             NaN     NaN     NaN     NaN       NaN
# start_hood             NaN     NaN     NaN     NaN       NaN
# ended_at               NaN     NaN     NaN     NaN       NaN
# end_station_name       NaN     NaN     NaN     NaN       NaN
# end_lat              40.63   40.72   40.74   40.76     40.88
# end_lng             -74.08  -73.99  -73.98  -73.96    -73.88
# end_boro               NaN     NaN     NaN     NaN       NaN
# end_hood               NaN     NaN     NaN     NaN       NaN
# year               2021.00 2021.00 2021.00 2021.00   2022.00
# month                 1.00    5.00    7.00    9.00     12.00
# week_of_year          1.00   19.00   29.00   39.00     52.00
# day_of_week           0.00    1.00    3.00    5.00      6.00
# hour_of_day           0.00   11.00   15.00   18.00     23.00
# duration_min          0.02    6.17   10.62   18.38 263605.68
# distance_mi           0.00    0.79    1.35    2.27     22.56
# speed_mph             0.00    6.27    8.40   10.63  11966.16

# %% [markdown]
# This improves the data a little by removing the infinity values at the maximum and minimum for **speed_mph**. Now, to examine the rest of the outlying data causing an absurdly high mean **duration_min**.

# %% [markdown]
# First, use the maximum distance ever traveled as a rule of thumb to assess how long a ride duration should be at its maximum.

# %%
CB_Data.sort_values(by=['distance_mi'], ascending = False).head()
# Out:
#          member_casual  rideable_type          started_at  \
# 18201184        Casual   Classic Bike 2021-10-05 11:44:58
# 21231254        Member  Electric Bike 2021-12-06 16:44:44
# 18764165        Member  Electric Bike 2021-11-10 17:16:39
# 2915557         Casual  Electric Bike 2021-06-17 18:33:57
# 14576500        Casual  Electric Bike 2021-09-08 17:10:48
#
#                start_station_name  start_lat  start_lng start_boro  \
# 18201184            45 St & 4 Ave      40.65     -74.01   Brooklyn
# 21231254        W 212 St & 10 Ave      40.87     -73.92  Manhattan
# 18764165    Bailey Ave & W 193 St      40.87     -73.91      Bronx
# 2915557             55 St & 7 Ave      40.64     -74.01   Brooklyn
# 14576500  Paul Ave & Mosholu Pkwy      40.88     -73.89      Bronx
#
#            start_hood            ended_at          end_station_name  end_lat  \
# 18201184  Sunset Park 2021-10-05 21:55:45    W 225 St & Exterior St    40.87
# 21231254       Inwood 2021-12-06 18:25:39             57 St & 4 Ave    40.64
# 18764165  Kingsbridge 2021-11-10 19:11:13             45 St & 4 Ave    40.65
# 2915557   Sunset Park 2021-06-17 20:21:27  Southern Blvd & E 175 St    40.84
# 14576500  Kingsbridge 2021-09-08 18:46:38              6 Ave & 9 St    40.67
#
#           end_lng  end_boro         end_hood  year  month  week_of_year  \
# 18201184   -73.91     Bronx      Kingsbridge  2021     10            40
# 21231254   -74.02  Brooklyn      Sunset Park  2021     12            49
# 18764165   -74.01  Brooklyn      Sunset Park  2021     11            45
# 2915557    -73.89     Bronx  East Morrisania  2021      6            24
# 14576500   -73.98  Brooklyn       Park Slope  2021      9            36
#
#           day_of_week  hour_of_day  duration_min  distance_mi  speed_mph
# 18201184            1           11        610.78        22.56       2.22
# 21231254            0           16        100.92        22.43      13.34
# 18764165            2           17        114.57        22.37      11.72
# 2915557             3           18        107.50        22.23      12.41
# 14576500            2           17         95.83        21.38      13.39

# %% [markdown]
# A 22.56-mile ride from Sunset Park in Brooklyn to Kingsbridge in the Bronx is long, but should not take more than ten hours to complete. Therefore, examine what the average travel times for such rides are in order to develop an idea as to how long such an extreme distance shuld take on average.

# %%
CB_sp_kb = CB_Data.loc[(CB_Data.start_hood == 'Sunset Park') & (CB_Data.end_hood == 'Kingsbridge')]

# %%
CB_sp_kb.describe(include='all').T
# Out:
#                    count unique                         top freq  \
# member_casual          2      1                      Casual    2
# rideable_type          2      2               Electric Bike    1
# started_at             2      2         2021-07-17 19:08:59    1
# start_station_name     2      2               34 St & 4 Ave    1
# start_lat           2.00    NaN                         NaN  NaN
# start_lng           2.00    NaN                         NaN  NaN
# start_boro             2      1                    Brooklyn    2
# start_hood             2      1                 Sunset Park    2
# ended_at               2      2         2021-07-17 21:21:02    1
# end_station_name       2      2  W Fordham Rd & Loring Pl N    1
# end_lat             2.00    NaN                         NaN  NaN
# end_lng             2.00    NaN                         NaN  NaN
# end_boro               2      1                       Bronx    2
# end_hood               2      1                 Kingsbridge    2
# year                2.00    NaN                         NaN  NaN
# month               2.00    NaN                         NaN  NaN
# week_of_year        2.00    NaN                         NaN  NaN
# day_of_week         2.00    NaN                         NaN  NaN
# hour_of_day         2.00    NaN                         NaN  NaN
# duration_min        2.00    NaN                         NaN  NaN
# distance_mi         2.00    NaN                         NaN  NaN
# speed_mph           2.00    NaN                         NaN  NaN
#
#                                  first                last    mean    std  \
# member_casual                      NaT                 NaT     NaN    NaN
# rideable_type                      NaT                 NaT     NaN    NaN
# started_at         2021-07-17 19:08:59 2021-10-05 11:44:58     NaN    NaN
# start_station_name                 NaT                 NaT     NaN    NaN
# start_lat                          NaT                 NaT   40.65   0.00
# start_lng                          NaT                 NaT  -74.01   0.00
# start_boro                         NaT                 NaT     NaN    NaN
# start_hood                         NaT                 NaT     NaN    NaN
# ended_at           2021-07-17 21:21:02 2021-10-05 21:55:45     NaN    NaN
# end_station_name                   NaT                 NaT     NaN    NaN
# end_lat                            NaT                 NaT   40.87   0.01
# end_lng                            NaT                 NaT  -73.91   0.00
# end_boro                           NaT                 NaT     NaN    NaN
# end_hood                           NaT                 NaT     NaN    NaN
# year                               NaT                 NaT 2021.00   0.00
# month                              NaT                 NaT    8.50   2.12
# week_of_year                       NaT                 NaT   34.00   8.49
# day_of_week                        NaT                 NaT    3.00   2.83
# hour_of_day                        NaT                 NaT   15.00   5.66
# duration_min                       NaT                 NaT  371.42 338.52
# distance_mi                        NaT                 NaT   21.75   1.15
# speed_mph                          NaT                 NaT    5.86   5.16
#
#                        min     25%     50%     75%     max
# member_casual          NaN     NaN     NaN     NaN     NaN
# rideable_type          NaN     NaN     NaN     NaN     NaN
# started_at             NaN     NaN     NaN     NaN     NaN
# start_station_name     NaN     NaN     NaN     NaN     NaN
# start_lat            40.65   40.65   40.65   40.65   40.66
# start_lng           -74.01  -74.01  -74.01  -74.00  -74.00
# start_boro             NaN     NaN     NaN     NaN     NaN
# start_hood             NaN     NaN     NaN     NaN     NaN
# ended_at               NaN     NaN     NaN     NaN     NaN
# end_station_name       NaN     NaN     NaN     NaN     NaN
# end_lat              40.86   40.87   40.87   40.87   40.87
# end_lng             -73.91  -73.91  -73.91  -73.91  -73.91
# end_boro               NaN     NaN     NaN     NaN     NaN
# end_hood               NaN     NaN     NaN     NaN     NaN
# year               2021.00 2021.00 2021.00 2021.00 2021.00
# month                 7.00    7.75    8.50    9.25   10.00
# week_of_year         28.00   31.00   34.00   37.00   40.00
# day_of_week           1.00    2.00    3.00    4.00    5.00
# hour_of_day          11.00   13.00   15.00   17.00   19.00
# duration_min        132.05  251.73  371.42  491.10  610.78
# distance_mi          20.93   21.34   21.75   22.15   22.56
# speed_mph             2.22    4.04    5.86    7.69    9.51

# %%
plt.figure(figsize=(18,9))
sns.kdeplot(CB_sp_kb.duration_min)
plt.show()

# %%
# Visualizing mean, median, and mode for ride duration.
plt.figure(figsize = (18,9))
CB_sp_kb.duration_min.plot(kind='density')
plt.axvline(CB_sp_kb.duration_min.mean(), label='Mean')
plt.axvline(CB_sp_kb.duration_min.median(), label='Median')
plt.axvline(statistics.mode(CB_sp_kb.duration_min), label='Mode')
plt.boxplot
# Out:
# <function matplotlib.pyplot.boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_ticks=True, autorange=False, zorder=None, *, data=None)>

# %%
print(f'The average ride duration to travel from Sunset Park to Kingsbridge is: {CB_sp_kb.duration_min.mean()} min.')
print(f'This brings the average ride speed to: {CB_sp_kb.distance_mi.max()/(CB_sp_kb.duration_min.mean()/60)} mph.')
print(f'The median ride duration to travel from Sunset Park to Kingsbridge is: {CB_sp_kb.duration_min.median()} min.')
print(f'This brings the median ride speed to: {CB_sp_kb.distance_mi.max()/(CB_sp_kb.duration_min.mean()/60)} mph.')
print(f'The most common ride duration to travel from Sunset Park to Kingsbridge is: {statistics.mode(CB_sp_kb.duration_min)} min.')
print(f'This brings the typical ride speed to: {CB_sp_kb.distance_mi.max()/(statistics.mode(CB_sp_kb.duration_min)/60)} mph.')
# Out:
# The average ride duration to travel from Sunset Park to Kingsbridge is: 371.41666666666663 min.
# This brings the average ride speed to: 3.6444765219750255 mph.
# The median ride duration to travel from Sunset Park to Kingsbridge is: 371.41666666666663 min.
# This brings the median ride speed to: 3.6444765219750255 mph.
# The most common ride duration to travel from Sunset Park to Kingsbridge is: 132.05 min.
# This brings the typical ride speed to: 10.250808947647789 mph.

# %% [markdown]
# Therefore, these seems to be a lot of junk ride data suggesting that it would take more than six hours on average to ride 22.56 miles at speed of 3.64 mph, which is basically walking speed. A travel time of slightly more than two hours seems more reasonable. Therefore, an maximum ride cap of 2.5 hours (150 min) should be assumed in order to provide some bubble of safety for this extreme case.

# %%
CB_Data.loc[CB_Data.duration_min <= 150].describe(include='all').T
# Out:
#                          count    unique                  top      freq  \
# member_casual         27073028         2               Member  20069367
# rideable_type         27073028         2         Classic Bike  19412320
# started_at            27073028  15030160  2021-08-20 17:29:55        40
# start_station_name    27073028      1588      W 21 St & 6 Ave    127886
# start_lat          27073028.00       NaN                  NaN       NaN
# start_lng          27073028.00       NaN                  NaN       NaN
# start_boro            27073028         5            Manhattan  19625980
# start_hood            27073028        89              Chelsea   2069575
# ended_at              27073028  15041555  2021-05-05 23:31:09        60
# end_station_name      27073028      1663      W 21 St & 6 Ave    128965
# end_lat            27073028.00       NaN                  NaN       NaN
# end_lng            27073028.00       NaN                  NaN       NaN
# end_boro              27073028         5            Manhattan  19591964
# end_hood              27073028        90              Chelsea   2073955
# year               27073028.00       NaN                  NaN       NaN
# month              27073028.00       NaN                  NaN       NaN
# week_of_year       27073028.00       NaN                  NaN       NaN
# day_of_week        27073028.00       NaN                  NaN       NaN
# hour_of_day        27073028.00       NaN                  NaN       NaN
# duration_min       27073028.00       NaN                  NaN       NaN
# distance_mi        27073028.00       NaN                  NaN       NaN
# speed_mph          27073028.00       NaN                  NaN       NaN
#
#                                  first                last    mean   std  \
# member_casual                      NaT                 NaT     NaN   NaN
# rideable_type                      NaT                 NaT     NaN   NaN
# started_at         2021-05-01 00:00:01 2022-04-30 23:59:59     NaN   NaN
# start_station_name                 NaT                 NaT     NaN   NaN
# start_lat                          NaT                 NaT   40.74  0.04
# start_lng                          NaT                 NaT  -73.98  0.02
# start_boro                         NaT                 NaT     NaN   NaN
# start_hood                         NaT                 NaT     NaN   NaN
# ended_at           2021-05-01 00:02:01 2022-05-01 01:36:58     NaN   NaN
# end_station_name                   NaT                 NaT     NaN   NaN
# end_lat                            NaT                 NaT   40.74  0.04
# end_lng                            NaT                 NaT  -73.98  0.02
# end_boro                           NaT                 NaT     NaN   NaN
# end_hood                           NaT                 NaT     NaN   NaN
# year                               NaT                 NaT 2021.23  0.42
# month                              NaT                 NaT    7.03  2.99
# week_of_year                       NaT                 NaT   28.45 12.91
# day_of_week                        NaT                 NaT    2.97  1.95
# hour_of_day                        NaT                 NaT   14.05  5.02
# duration_min                       NaT                 NaT   14.42 13.14
# distance_mi                        NaT                 NaT    1.76  1.43
# speed_mph                          NaT                 NaT    8.48  5.26
#
#                        min     25%     50%     75%      max
# member_casual          NaN     NaN     NaN     NaN      NaN
# rideable_type          NaN     NaN     NaN     NaN      NaN
# started_at             NaN     NaN     NaN     NaN      NaN
# start_station_name     NaN     NaN     NaN     NaN      NaN
# start_lat            40.63   40.72   40.74   40.76    40.88
# start_lng           -74.04  -73.99  -73.98  -73.96   -73.88
# start_boro             NaN     NaN     NaN     NaN      NaN
# start_hood             NaN     NaN     NaN     NaN      NaN
# ended_at               NaN     NaN     NaN     NaN      NaN
# end_station_name       NaN     NaN     NaN     NaN      NaN
# end_lat              40.63   40.72   40.74   40.76    40.88
# end_lng             -74.08  -73.99  -73.98  -73.96   -73.88
# end_boro               NaN     NaN     NaN     NaN      NaN
# end_hood               NaN     NaN     NaN     NaN      NaN
# year               2021.00 2021.00 2021.00 2021.00  2022.00
# month                 1.00    5.00    7.00    9.00    12.00
# week_of_year          1.00   19.00   29.00   39.00    52.00
# day_of_week           0.00    1.00    3.00    5.00     6.00
# hour_of_day           0.00   11.00   15.00   18.00    23.00
# duration_min          0.02    6.17   10.60   18.30   150.00
# distance_mi           0.00    0.79    1.35    2.27    22.43
# speed_mph             0.00    6.29    8.41   10.63 11966.16

# %% [markdown]
# This provides a further improvement over the dataset by normalizing the **duration_min** and **distance_mi** by a great amount. Now, it is the absurdly high maximum **speed_mph** that needs to be investigated.

# %%
CB_Data = CB_Data.loc[CB_Data.duration_min <= 150]

# %%
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.speed_mph)
plt.show()

# %%
CB_Data.sort_values(by=['speed_mph'], ascending = False).head()
# Out:
#          member_casual rideable_type          started_at  \
# 25486948        Member  Classic Bike 2022-03-19 13:06:11
# 1161527         Member  Classic Bike 2021-05-20 09:12:19
# 1481681         Casual  Classic Bike 2021-05-09 14:22:07
# 692576          Member  Classic Bike 2021-05-04 16:21:38
# 25734125        Member  Classic Bike 2022-03-03 18:04:47
#
#              start_station_name  start_lat  start_lng start_boro  \
# 25486948    Murray St & West St      40.71     -74.01  Manhattan
# 1161527     21 Ave & Shore Blvd      40.78     -73.92     Queens
# 1481681   Mercer St & Spring St      40.72     -74.00  Manhattan
# 692576       Broadway & W 38 St      40.75     -73.99  Manhattan
# 25734125        W 55 St & 6 Ave      40.76     -73.98  Manhattan
#
#                 start_hood            ended_at      end_station_name  end_lat  \
# 25486948           Tribeca 2022-03-19 13:06:14  Lenox Ave & W 111 St    40.80
# 1161527   Ditmars Steinway 2021-05-20 09:12:20        31 Ave & 30 St    40.76
# 1481681               SoHo 2021-05-09 14:22:08       E 11 St & 1 Ave    40.73
# 692576             Midtown 2021-05-04 16:21:43        West Thames St    40.71
# 25734125           Midtown 2022-03-03 18:04:54   Clark St & Henry St    40.70
#
#           end_lng   end_boro           end_hood  year  month  week_of_year  \
# 25486948   -73.95  Manhattan             Harlem  2022      3            11
# 1161527    -73.92     Queens            Astoria  2021      5            20
# 1481681    -73.98  Manhattan       East Village  2021      5            18
# 692576     -74.02  Manhattan  Battery Park City  2021      5            18
# 25734125   -73.99   Brooklyn   Brooklyn Heights  2022      3             9
#
#           day_of_week  hour_of_day  duration_min  distance_mi  speed_mph
# 25486948            5           13          0.05         9.97   11966.16
# 1161527             3            9          0.02         1.82    6556.02
# 1481681             6           14          0.02         1.46    5250.95
# 692576              1           16          0.08         5.13    3696.81
# 25734125            3           18          0.12         5.56    2860.10

# %% [markdown]
# It appears that for these rides, there seems to be some irregularity with respect to their being assigned to their tracking devices, particularly for the distances being traveled. Therfore, assume that all rides are at least 1 min to begin trimming down this set of junk data.

# %%
CB_Data = CB_Data.loc[CB_Data.duration_min >= 1]

# %%
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.speed_mph)
plt.show()

# %% [markdown]
# The data appears more digestible, but such unnaturally high speed bike rides still have not been eliminated. Time for a second look.

# %%
CB_Data.sort_values(by=['speed_mph'], ascending = False).head()
# Out:
#          member_casual rideable_type          started_at  \
# 24818936        Member  Classic Bike 2022-03-09 18:11:53
# 24806384        Member  Classic Bike 2022-03-19 17:32:11
# 25722027        Member  Classic Bike 2022-03-04 07:37:55
# 1257548         Casual  Classic Bike 2021-05-16 14:00:26
# 28687336        Member  Classic Bike 2022-04-21 08:27:14
#
#                    start_station_name  start_lat  start_lng start_boro  \
# 24818936   Van Brunt St & Van Dyke St      40.68     -74.01   Brooklyn
# 24806384      Lexington Ave & E 26 St      40.74     -73.98  Manhattan
# 25722027      West End Ave & W 107 St      40.80     -73.97  Manhattan
# 1257548              W 20 St & 10 Ave      40.75     -74.01  Manhattan
# 28687336  Willoughby Ave & Myrtle Ave      40.70     -73.93   Brooklyn
#
#                start_hood            ended_at          end_station_name  \
# 24818936         Red Hook 2022-03-09 18:12:55  Union Ave & Wallabout St
# 24806384         Kips Bay 2022-03-19 17:33:20      Lenox Ave & W 117 St
# 25722027  Upper West Side 2022-03-04 07:39:32       Clark St & Henry St
# 1257548           Chelsea 2021-05-16 14:01:33    Riverside Dr & W 91 St
# 28687336         Bushwick 2022-04-21 08:28:53        Carmine St & 6 Ave
#
#           end_lat  end_lng   end_boro          end_hood  year  month  \
# 24818936    40.70   -73.95   Brooklyn      Williamsburg  2022      3
# 24806384    40.80   -73.95  Manhattan            Harlem  2022      3
# 25722027    40.70   -73.99   Brooklyn  Brooklyn Heights  2022      3
# 1257548     40.79   -73.98  Manhattan   Upper West Side  2021      5
# 28687336    40.73   -74.00  Manhattan      West Village  2022      4
#
#           week_of_year  day_of_week  hour_of_day  duration_min  distance_mi  \
# 24818936            10            2           18          1.03         6.13
# 24806384            11            5           17          1.15         6.58
# 25722027             9            4            7          1.62         8.95
# 1257548             19            6           14          1.12         5.22
# 28687336            16            3            8          1.65         7.18
#
#           speed_mph
# 24818936     356.03
# 24806384     343.12
# 25722027     332.35
# 1257548      280.23
# 28687336     260.91

# %% [markdown]
# Raise the threshold to two minutes, just for a careful increment to prevent too much data loss.

# %%
CB_Data = CB_Data.loc[CB_Data.duration_min >= 2]

# %%
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.speed_mph)
plt.show()

# %%
CB_Data.sort_values(by=['speed_mph'], ascending = False).head()
# Out:
#          member_casual rideable_type          started_at  \
# 879927          Member  Classic Bike 2021-05-03 15:05:56
# 25734525        Member  Classic Bike 2022-03-03 18:40:33
# 25476207        Member  Classic Bike 2022-03-25 22:22:27
# 25494375        Member  Classic Bike 2022-03-22 12:01:07
# 25489225        Member  Classic Bike 2022-03-25 22:55:18
#
#                    start_station_name  start_lat  start_lng start_boro  \
# 879927               W 43 St & 10 Ave      40.76     -73.99  Manhattan
# 25734525         Lenox Ave & W 111 St      40.80     -73.95  Manhattan
# 25476207  Greenwich St & W Houston St      40.73     -74.01  Manhattan
# 25494375              E 11 St & 3 Ave      40.73     -73.99  Manhattan
# 25489225            6 Ave & Broome St      40.72     -74.00  Manhattan
#
#               start_hood            ended_at  \
# 879927    Hell's Kitchen 2021-05-03 15:08:17
# 25734525          Harlem 2022-03-03 18:43:26
# 25476207            SoHo 2022-03-25 22:25:16
# 25494375    East Village 2022-03-22 12:03:33
# 25489225            SoHo 2022-03-25 22:58:18
#
#                             end_station_name  end_lat  end_lng   end_boro  \
# 879927    W 155 St & Frederick Douglass Blvd    40.83   -73.94  Manhattan
# 25734525                 Clark St & Henry St    40.70   -73.99   Brooklyn
# 25476207                Lenox Ave & W 111 St    40.80   -73.95  Manhattan
# 25494375                Lenox Ave & W 111 St    40.80   -73.95  Manhattan
# 25489225                Lenox Ave & W 111 St    40.80   -73.95  Manhattan
#
#                     end_hood  year  month  week_of_year  day_of_week  \
# 879927    Washington Heights  2021      5            18            0
# 25734525    Brooklyn Heights  2022      3             9            3
# 25476207              Harlem  2022      3            12            4
# 25494375              Harlem  2022      3            12            1
# 25489225              Harlem  2022      3            12            4
#
#           hour_of_day  duration_min  distance_mi  speed_mph
# 879927             15          2.35         8.75     223.31
# 25734525           18          2.88         9.82     204.36
# 25476207           22          2.82         8.71     185.54
# 25494375           12          2.43         7.16     176.44
# 25489225           22          3.00         8.76     175.13

# %% [markdown]
# Step it up to five minutes.

# %%
CB_Data = CB_Data.loc[CB_Data.duration_min >= 5]

# %%
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.speed_mph)
plt.show()

# %% [markdown]
# Since it is a rule of thumb that eBikes at the most cannot travel faster than 20 mph, eliminate rides that exceed that value.

# %%
CB_Data = CB_Data.loc[CB_Data.speed_mph <= 20]

# %%
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.speed_mph)
plt.show()

# %% [markdown]
# Finally, it is not possible that rides go at 0 mph, therefore assume that they are at least 1 mph to assume a sloppy ride from one station to another due to a rider changing one's mind about riding or choice of bike.

# %%
CB_Data = CB_Data.loc[CB_Data.speed_mph >= 1]

# %%
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.speed_mph)
plt.show()

# %%
CB_Data.sort_values(by=['speed_mph'], ascending = True).head()
# Out:
#          member_casual rideable_type          started_at  \
# 1301572         Member  Classic Bike 2021-05-14 16:56:28
# 3863847         Member  Classic Bike 2021-06-29 12:57:19
# 13279634        Member  Classic Bike 2021-09-30 18:38:31
# 21004986        Member  Classic Bike 2021-12-21 13:31:40
# 13089231        Member  Classic Bike 2021-09-14 17:42:27
#
#                 start_station_name  start_lat  start_lng start_boro  \
# 1301572    Harrison St & Hudson St      40.72     -74.01  Manhattan
# 3863847            2 Ave & E 96 St      40.78     -73.95  Manhattan
# 13279634      21 Ave & Crescent St      40.78     -73.91     Queens
# 21004986  Amsterdam Ave & W 125 St      40.81     -73.96  Manhattan
# 13089231       Union Ave & N 12 St      40.72     -73.95   Brooklyn
#
#                    start_hood            ended_at      end_station_name  \
# 1301572               Tribeca 2021-05-14 17:07:05  Hudson St & Reade St
# 3863847       Upper East Side 2021-06-29 13:15:01       E 95 St & 3 Ave
# 13279634     Ditmars Steinway 2021-09-30 19:12:18   21 Ave & Shore Blvd
# 21004986  Morningside Heights 2021-12-21 14:08:27     12 Ave & W 125 St
# 13089231           Greenpoint 2021-09-14 18:25:20     Kent Ave & N 7 St
#
#           end_lat  end_lng   end_boro          end_hood  year  month  \
# 1301572     40.72   -74.01  Manhattan           Tribeca  2021      5
# 3863847     40.78   -73.95  Manhattan   Upper East Side  2021      6
# 13279634    40.78   -73.92     Queens  Ditmars Steinway  2021      9
# 21004986    40.82   -73.96  Manhattan            Harlem  2021     12
# 13089231    40.72   -73.96   Brooklyn      Williamsburg  2021      9
#
#           week_of_year  day_of_week  hour_of_day  duration_min  distance_mi  \
# 1301572             19            4           16         10.62         0.18
# 3863847             26            1           12         17.70         0.30
# 13279634            39            3           18         33.78         0.56
# 21004986            51            1           13         36.78         0.61
# 13089231            37            1           17         42.88         0.71
#
#           speed_mph
# 1301572        1.00
# 3863847        1.00
# 13279634       1.00
# 21004986       1.00
# 13089231       1.00

# %% [markdown]
# That one kink in the curve probably indicates riders riding around without a specific purpose in mind and is better to eliminate entirely in order to smooth out the density curve. Since a typical human walking speed is estimated to be 3 - 4 mph, it makes no sense to ride a bike to not exceed that. Therefore, set 5 mph as a the minimum speed for bike rides, since below that assumes too much unusual conditions in the ride itself.

# %%
CB_Data = CB_Data.loc[CB_Data.speed_mph >= 5]

# %%
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.speed_mph)
plt.show()

# %%
CB_Data.sort_values(by=['speed_mph'], ascending = True).head()
# Out:
#          member_casual rideable_type          started_at  \
# 14595383        Casual  Classic Bike 2021-09-04 22:21:16
# 434799          Member  Classic Bike 2021-05-16 18:54:23
# 9910684         Casual  Classic Bike 2021-08-28 15:34:25
# 16954339        Member  Classic Bike 2021-10-10 16:40:19
# 9746510         Member  Classic Bike 2021-08-13 21:41:39
#
#                start_station_name  start_lat  start_lng start_boro  \
# 14595383      Reade St & Broadway      40.71     -74.01  Manhattan
# 434799            1 Ave & E 78 St      40.77     -73.95  Manhattan
# 9910684      William St & Pine St      40.71     -74.01  Manhattan
# 16954339            34 St & 4 Ave      40.66     -74.00   Brooklyn
# 9746510   Clinton St\t& Cherry St      40.71     -73.99  Manhattan
#
#                   start_hood            ended_at         end_station_name  \
# 14595383        Civic Center 2021-09-04 22:45:47        E 2 St & Avenue B
# 434799       Upper East Side 2021-05-16 19:14:24          E 58 St & 3 Ave
# 9910684   Financial District 2021-08-28 15:55:48    Mercer St & Spring St
# 16954339         Sunset Park 2021-10-10 16:46:56            41 St & 4 Ave
# 9746510      Lower East Side 2021-08-13 21:51:34  Allen St & Rivington St
#
#           end_lat  end_lng   end_boro         end_hood  year  month  \
# 14595383    40.72   -73.98  Manhattan     East Village  2021      9
# 434799      40.76   -73.97  Manhattan          Midtown  2021      5
# 9910684     40.72   -74.00  Manhattan             SoHo  2021      8
# 16954339    40.65   -74.01   Brooklyn      Sunset Park  2021     10
# 9746510     40.72   -73.99  Manhattan  Lower East Side  2021      8
#
#           week_of_year  day_of_week  hour_of_day  duration_min  distance_mi  \
# 14595383            35            5           22         24.52         2.04
# 434799              19            6           18         20.02         1.67
# 9910684             34            5           15         21.38         1.78
# 16954339            40            6           16          6.62         0.55
# 9746510             32            4           21          9.92         0.83
#
#           speed_mph
# 14595383       5.00
# 434799         5.00
# 9910684        5.00
# 16954339       5.00
# 9746510        5.00

# %%
# Visualizing mean, median, and mode for ride speed.
plt.figure(figsize = (18,9))
CB_Data.speed_mph.plot(kind='density')
plt.axvline(CB_Data.speed_mph.mean(), label='Mean')
plt.axvline(CB_Data.speed_mph.median(), label='Median')
plt.axvline(statistics.mode(CB_Data.speed_mph), label='Mode')
plt.boxplot
# Out:
# <function matplotlib.pyplot.boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_ticks=True, autorange=False, zorder=None, *, data=None)>

# %%
print(f'The average ride speed is: {CB_Data.speed_mph.mean()} mph.')
print(f'The median ride speed is: {CB_Data.speed_mph.mean()} mph.')
print(f'The typical ride speed is: {statistics.mode(CB_Data.speed_mph)} mph.')
# Out:
# The average ride speed is: 9.2167567178771 mph.
# The median ride speed is: 9.2167567178771 mph.
# The typical ride speed is: 9.582826362943905 mph.

# %%
CB_Data.describe(include='all').T
# Out:
#                          count    unique                  top      freq  \
# member_casual         18658426         2               Member  13885173
# rideable_type         18658426         2         Classic Bike  13019655
# started_at            18658426  12040084  2021-06-25 19:08:09        27
# start_station_name    18658426      1587      W 21 St & 6 Ave     84118
# start_lat          18658426.00       NaN                  NaN       NaN
# start_lng          18658426.00       NaN                  NaN       NaN
# start_boro            18658426         5            Manhattan  13542212
# start_hood            18658426        89              Chelsea   1429536
# ended_at              18658426  12033810  2021-05-05 23:31:09        36
# end_station_name      18658426      1654      W 21 St & 6 Ave     88605
# end_lat            18658426.00       NaN                  NaN       NaN
# end_lng            18658426.00       NaN                  NaN       NaN
# end_boro              18658426         5            Manhattan  13522531
# end_hood              18658426        90              Chelsea   1439245
# year               18658426.00       NaN                  NaN       NaN
# month              18658426.00       NaN                  NaN       NaN
# week_of_year       18658426.00       NaN                  NaN       NaN
# day_of_week        18658426.00       NaN                  NaN       NaN
# hour_of_day        18658426.00       NaN                  NaN       NaN
# duration_min       18658426.00       NaN                  NaN       NaN
# distance_mi        18658426.00       NaN                  NaN       NaN
# speed_mph          18658426.00       NaN                  NaN       NaN
#
#                                  first                last    mean   std  \
# member_casual                      NaT                 NaT     NaN   NaN
# rideable_type                      NaT                 NaT     NaN   NaN
# started_at         2021-05-01 00:00:01 2022-04-30 23:59:59     NaN   NaN
# start_station_name                 NaT                 NaT     NaN   NaN
# start_lat                          NaT                 NaT   40.74  0.04
# start_lng                          NaT                 NaT  -73.98  0.02
# start_boro                         NaT                 NaT     NaN   NaN
# start_hood                         NaT                 NaT     NaN   NaN
# ended_at           2021-05-01 00:06:03 2022-05-01 00:48:28     NaN   NaN
# end_station_name                   NaT                 NaT     NaN   NaN
# end_lat                            NaT                 NaT   40.74  0.04
# end_lng                            NaT                 NaT  -73.98  0.02
# end_boro                           NaT                 NaT     NaN   NaN
# end_hood                           NaT                 NaT     NaN   NaN
# year                               NaT                 NaT 2021.22  0.42
# month                              NaT                 NaT    7.04  2.98
# week_of_year                       NaT                 NaT   28.52 12.87
# day_of_week                        NaT                 NaT    2.94  1.94
# hour_of_day                        NaT                 NaT   14.03  5.03
# duration_min                       NaT                 NaT   14.50  9.31
# distance_mi                        NaT                 NaT    2.18  1.47
# speed_mph                          NaT                 NaT    9.22  2.67
#
#                        min     25%     50%     75%     max
# member_casual          NaN     NaN     NaN     NaN     NaN
# rideable_type          NaN     NaN     NaN     NaN     NaN
# started_at             NaN     NaN     NaN     NaN     NaN
# start_station_name     NaN     NaN     NaN     NaN     NaN
# start_lat            40.63   40.72   40.74   40.76   40.88
# start_lng           -74.04  -73.99  -73.98  -73.96  -73.88
# start_boro             NaN     NaN     NaN     NaN     NaN
# start_hood             NaN     NaN     NaN     NaN     NaN
# ended_at               NaN     NaN     NaN     NaN     NaN
# end_station_name       NaN     NaN     NaN     NaN     NaN
# end_lat              40.63   40.72   40.74   40.76   40.88
# end_lng             -74.08  -73.99  -73.98  -73.96  -73.88
# end_boro               NaN     NaN     NaN     NaN     NaN
# end_hood               NaN     NaN     NaN     NaN     NaN
# year               2021.00 2021.00 2021.00 2021.00 2022.00
# month                 1.00    5.00    7.00    9.00   12.00
# week_of_year          1.00   19.00   29.00   39.00   52.00
# day_of_week           0.00    1.00    3.00    5.00    6.00
# hour_of_day           0.00   10.00   15.00   18.00   23.00
# duration_min          5.00    7.92   11.67   18.13  149.90
# distance_mi           0.42    1.17    1.74    2.71   22.43
# speed_mph             5.00    7.16    8.84   10.85   20.00

# %% [markdown]
# This gradual reduction of outlier rides that are probably not legitimate ones seems to have calmed the extreme noise in the data. Finally, examine the overall distribution of data to check for any more iregularities.

# %%
# Distribution of ride durations (min)
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.duration_min)
plt.show()

# %%
# Distribution of ride distances (mi)
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.distance_mi)
plt.show()

# %%
# Distribution of ride speeds (mph)
plt.figure(figsize=(18,9))
sns.kdeplot(CB_Data.speed_mph)
plt.show()

# %%
CB_Data.loc[CB_Data.duration_min == CB_Data.duration_min.max()]
# Out:
#          member_casual rideable_type          started_at   start_station_name  \
# 11894480        Casual  Classic Bike 2021-08-26 12:58:59  King St & Varick St
#
#           start_lat  start_lng start_boro start_hood            ended_at  \
# 11894480      40.73     -74.01  Manhattan       SoHo 2021-08-26 15:28:53
#
#                end_station_name  end_lat  end_lng   end_boro end_hood  year  \
# 11894480  Dyckman St & Staff St    40.87   -73.93  Manhattan   Inwood  2021
#
#           month  week_of_year  day_of_week  hour_of_day  duration_min  \
# 11894480      8            34            3           12        149.90
#
#           distance_mi  speed_mph
# 11894480        14.82       5.93

# %%
CB_Data.loc[CB_Data.distance_mi == CB_Data.distance_mi.max()]
# Out:
#          member_casual  rideable_type          started_at start_station_name  \
# 21231254        Member  Electric Bike 2021-12-06 16:44:44  W 212 St & 10 Ave
#
#           start_lat  start_lng start_boro start_hood            ended_at  \
# 21231254      40.87     -73.92  Manhattan     Inwood 2021-12-06 18:25:39
#
#          end_station_name  end_lat  end_lng  end_boro     end_hood  year  \
# 21231254    57 St & 4 Ave    40.64   -74.02  Brooklyn  Sunset Park  2021
#
#           month  week_of_year  day_of_week  hour_of_day  duration_min  \
# 21231254     12            49            0           16        100.92
#
#           distance_mi  speed_mph
# 21231254        22.43      13.34

# %%
CB_Data.loc[CB_Data.speed_mph == CB_Data.speed_mph.max()]
# Out:
#        member_casual rideable_type          started_at start_station_name  \
# 223502        Member  Classic Bike 2021-05-21 00:20:19    E 63 St & 3 Ave
#
#         start_lat  start_lng start_boro       start_hood            ended_at  \
# 223502      40.76     -73.96  Manhattan  Upper East Side 2021-05-21 00:27:55
#
#                         end_station_name  end_lat  end_lng end_boro  \
# 223502  Queens Plaza North & Crescent St    40.75   -73.94   Queens
#
#                 end_hood  year  month  week_of_year  day_of_week  hour_of_day  \
# 223502  Long Island City  2021      5            20            4            0
#
#         duration_min  distance_mi  speed_mph
# 223502          7.60         2.53      20.00

# %% [markdown]
# This data at this point seems usable enough to warrant saving to a **.parquet** file to resume the rest of the machine learning time series analysis and modeling.

# %%
CB_Data.shape
# Out:
# (18658426, 22)

# %%
CB_Data_arrow = pa.Table.from_pandas(CB_Data)
pq.write_table(CB_Data_arrow, 'data/202105-202204-citibike-tripdata.parquet')
